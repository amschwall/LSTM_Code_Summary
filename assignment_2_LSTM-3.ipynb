# %% [markdown]
# # LSTM Code Summary

# %% [markdown]
# # Install Dependencies

# %%
#!pip uninstall -y torchao torchvision torchaudio torch
# !pip install numpy==1.26.4
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (1.26.4)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install -r requirements.txt


# %pip install torch==2.2.0 transformers==4.46.0 tokenizers==0.20.3 sentencepiece==0.1.99 tqdm==4.65
# !pip install torchvision
# Out:
# Collecting torch==2.2.0
#   Using cached torch-2.2.0-cp312-cp312-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: transformers==4.46.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (4.46.0)
# Requirement already satisfied: tokenizers==0.20.3 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (0.20.3)
# Collecting sentencepiece==0.1.99
#   Using cached sentencepiece-0.1.99.tar.gz (2.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [31 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Aaron\Downloads\Abby_project\abby_venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#         File "c:\Users\Aaron\Downloads\Abby_project\abby_venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\Users\Aaron\Downloads\Abby_project\abby_venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Aaron\AppData\Local\Temp\pip-build-env-wg_mkh1m\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Aaron\AppData\Local\Temp\pip-build-env-wg_mkh1m\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\Aaron\AppData\Local\Temp\pip-build-env-wg_mkh1m\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\Aaron\AppData\Local\Temp\pip-build-env-wg_mkh1m\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 126, in <module>
#         File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 408, in check_call
#           retcode = call(*popenargs, **kwargs)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 389, in call
#           with Popen(*popenargs, **kwargs) as p:
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1026, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1538, in _execute_child
#           hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       FileNotFoundError: [WinError 2] The system cannot find the file specified
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# # Tokenize

# %%
# !python get_codet5_embeddings.py --input train_code.txt \
--output train_code.pt
# !python get_codet5_embeddings.py --input train_summary.txt \
--output train_summary.pt --max_length 128

# !python get_codet5_embeddings.py --input val_code.txt \
--output val_code.pt
# !python get_codet5_embeddings.py --input val_summary.txt \
--output val_summary.pt --max_length 128
# Out:
# Training:  65%|██████▌   | 101932/156300 [2:10:01<1:11:48, 12.62it/s, loss=1.274, epoch=66]
# Loading tokenizer and model: Salesforce/codet5p-220m
# Model loaded.
# Embedding matrix shape: torch.Size([32100, 768])
#   Vocab size:     32100
#   Embedding dim:  768
# Loaded 50000 samples from train_code.txt
#
# Token length stats:
#   Mean: 78.4
#   Max:  512
#   Min:  8
#
# Saved to train_code.pt
# Tokenizing:   0%|          | 0/50000 [00:00<?, ?it/s]
# Tokenizing:   1%|          | 525/50000 [00:00<00:09, 5220.52it/s]
# Tokenizing:   2%|▏         | 1130/50000 [00:00<00:08, 5674.86it/s]
# Tokenizing:   3%|▎         | 1698/50000 [00:00<00:08, 5419.91it/s]
# Tokenizing:   5%|▍         | 2446/50000 [00:00<00:07, 6189.57it/s]
# Tokenizing:   6%|▌         | 3068/50000 [00:00<00:07, 5961.57it/s]
# Tokenizing:   8%|▊         | 3810/50000 [00:00<00:07, 6430.05it/s]
# Tokenizing:   9%|▉         | 4457/50000 [00:00<00:07, 6265.01it/s]
# Tokenizing:  10%|█         | 5087/50000 [00:00<00:07, 6146.00it/s]
# Tokenizing:  11%|█▏        | 5704/50000 [00:00<00:07, 5679.12it/s]
# Tokenizing:  13%|█▎        | 6279/50000 [00:01<00:08, 5199.86it/s]
# Tokenizing:  14%|█▍        | 6944/50000 [00:01<00:07, 5590.51it/s]
# Tokenizing:  15%|█▌        | 7644/50000 [00:01<00:07, 5981.13it/s]
# Tokenizing:  17%|█▋        | 8255/50000 [00:01<00:07, 5882.52it/s]
# Tokenizing:  18%|█▊        | 9059/50000 [00:01<00:06, 6491.13it/s]
# Tokenizing:  20%|██        | 10172/50000 [00:01<00:05, 7817.94it/s]
# Tokenizing:  22%|██▏       | 10966/50000 [00:01<00:05, 7459.06it/s]
# Tokenizing:  23%|██▎       | 11732/50000 [00:01<00:05, 7505.65it/s]
# Tokenizing:  25%|██▍       | 12491/50000 [00:01<00:05, 6742.41it/s]
# Tokenizing:  26%|██▋       | 13184/50000 [00:02<00:05, 6489.42it/s]
# Tokenizing:  28%|██▊       | 13847/50000 [00:02<00:05, 6492.43it/s]
# Tokenizing:  29%|██▉       | 14506/50000 [00:02<00:05, 6294.32it/s]
# Tokenizing:  30%|███       | 15143/50000 [00:02<00:05, 6048.43it/s]
# Tokenizing:  32%|███▏      | 15753/50000 [00:02<00:05, 5866.25it/s]
# Tokenizing:  33%|███▎      | 16467/50000 [00:02<00:05, 6200.26it/s]
# Tokenizing:  34%|███▍      | 17093/50000 [00:02<00:05, 6207.54it/s]
# Tokenizing:  35%|███▌      | 17718/50000 [00:02<00:05, 6101.15it/s]
# Tokenizing:  37%|███▋      | 18331/50000 [00:02<00:05, 5787.89it/s]
# Tokenizing:  38%|███▊      | 19121/50000 [00:03<00:04, 6362.52it/s]
# Tokenizing:  40%|███▉      | 19896/50000 [00:03<00:04, 6747.94it/s]
# Tokenizing:  41%|████      | 20578/50000 [00:03<00:04, 6571.52it/s]
# Tokenizing:  42%|████▏     | 21241/50000 [00:03<00:04, 6417.80it/s]
# Tokenizing:  44%|████▍     | 21887/50000 [00:03<00:04, 6102.18it/s]
# Tokenizing:  45%|████▌     | 22503/50000 [00:03<00:04, 6052.55it/s]
# Tokenizing:  47%|████▋     | 23253/50000 [00:03<00:04, 6453.17it/s]
# Tokenizing:  48%|████▊     | 23903/50000 [00:03<00:04, 6052.55it/s]
# Tokenizing:  49%|████▉     | 24563/50000 [00:03<00:04, 6197.64it/s]
# Tokenizing:  50%|█████     | 25189/50000 [00:04<00:04, 5934.92it/s]
# Tokenizing:  52%|█████▏    | 25834/50000 [00:04<00:03, 6069.84it/s]
# Tokenizing:  53%|█████▎    | 26538/50000 [00:04<00:03, 6335.67it/s]
# Tokenizing:  54%|█████▍    | 27188/50000 [00:04<00:03, 6368.76it/s]
# Tokenizing:  56%|█████▌    | 27829/50000 [00:04<00:03, 6367.73it/s]
# Tokenizing:  57%|█████▋    | 28469/50000 [00:04<00:03, 5418.61it/s]
# Tokenizing:  58%|█████▊    | 29037/50000 [00:04<00:03, 5439.76it/s]
# Tokenizing:  59%|█████▉    | 29599/50000 [00:04<00:03, 5340.61it/s]
# Tokenizing:  60%|██████    | 30207/50000 [00:04<00:03, 5537.12it/s]
# Tokenizing:  62%|██████▏   | 30841/50000 [00:05<00:03, 5756.18it/s]
# Tokenizing:  63%|██████▎   | 31511/50000 [00:05<00:03, 6021.63it/s]
# Tokenizing:  64%|██████▍   | 32155/50000 [00:05<00:02, 6132.57it/s]
# Tokenizing:  66%|██████▌   | 32774/50000 [00:05<00:02, 6131.51it/s]
# Tokenizing:  67%|██████▋   | 33391/50000 [00:05<00:02, 6103.18it/s]
# Tokenizing:  68%|██████▊   | 34004/50000 [00:05<00:02, 6076.54it/s]
# Tokenizing:  69%|██████▉   | 34731/50000 [00:05<00:02, 6426.43it/s]
# Tokenizing:  71%|███████   | 35376/50000 [00:05<00:02, 6404.35it/s]
# Tokenizing:  72%|███████▏  | 36018/50000 [00:05<00:02, 6316.19it/s]
# Tokenizing:  74%|███████▎  | 36782/50000 [00:05<00:01, 6698.72it/s]
# Tokenizing:  75%|███████▍  | 37454/50000 [00:06<00:01, 6323.48it/s]
# Tokenizing:  76%|███████▌  | 38092/50000 [00:06<00:01, 6309.82it/s]
# Tokenizing:  77%|███████▋  | 38727/50000 [00:06<00:02, 4375.46it/s]
# Tokenizing:  79%|███████▊  | 39294/50000 [00:06<00:02, 4657.02it/s]
# Tokenizing:  80%|████████  | 40246/50000 [00:06<00:01, 5816.69it/s]
# Tokenizing:  82%|████████▏ | 40903/50000 [00:06<00:01, 5788.04it/s]
# Tokenizing:  83%|████████▎ | 41580/50000 [00:06<00:01, 6028.11it/s]
# Tokenizing:  84%|████████▍ | 42223/50000 [00:06<00:01, 6010.64it/s]
# Tokenizing:  86%|████████▌ | 42852/50000 [00:07<00:01, 5949.03it/s]
# Tokenizing:  87%|████████▋ | 43467/50000 [00:07<00:01, 5873.40it/s]
# Tokenizing:  88%|████████▊ | 44068/50000 [00:07<00:01, 5742.04it/s]
# Tokenizing:  90%|████████▉ | 44763/50000 [00:07<00:00, 6062.57it/s]
# Tokenizing:  91%|█████████ | 45453/50000 [00:07<00:00, 6291.64it/s]
# Tokenizing:  92%|█████████▏| 46090/50000 [00:07<00:00, 5998.77it/s]
# Tokenizing:  93%|█████████▎| 46698/50000 [00:07<00:00, 5953.16it/s]
# Tokenizing:  95%|█████████▌| 47554/50000 [00:07<00:00, 6675.02it/s]
# Tokenizing:  97%|█████████▋| 48352/50000 [00:07<00:00, 7039.59it/s]
# Tokenizing:  98%|█████████▊| 49063/50000 [00:08<00:00, 6317.18it/s]
# Tokenizing:  99%|█████████▉| 49718/50000 [00:08<00:00, 6374.81it/s]
# Tokenizing: 100%|██████████| 50000/50000 [00:08<00:00, 6125.74it/s]
# Loading tokenizer and model: Salesforce/codet5p-220m
# Model loaded.
# Embedding matrix shape: torch.Size([32100, 768])
#   Vocab size:     32100
#   Embedding dim:  768
# Loaded 50000 samples from train_summary.txt
#
# Token length stats:
#   Mean: 13.9
#   Max:  128
#   Min:  5
#
# Saved to train_summary.pt
# Tokenizing:   0%|          | 0/50000 [00:00<?, ?it/s]
# Tokenizing:   4%|▎         | 1771/50000 [00:00<00:02, 17583.70it/s]
# Tokenizing:   8%|▊         | 3831/50000 [00:00<00:02, 19281.33it/s]
# Tokenizing:  12%|█▏        | 6056/50000 [00:00<00:02, 20625.96it/s]
# Tokenizing:  17%|█▋        | 8353/50000 [00:00<00:01, 21537.39it/s]
# Tokenizing:  23%|██▎       | 11283/50000 [00:00<00:01, 24285.02it/s]
# Tokenizing:  28%|██▊       | 13816/50000 [00:00<00:01, 24566.16it/s]
# Tokenizing:  33%|███▎      | 16273/50000 [00:00<00:01, 24455.78it/s]
# Tokenizing:  37%|███▋      | 18719/50000 [00:00<00:01, 24390.54it/s]
# Tokenizing:  42%|████▏     | 21205/50000 [00:00<00:01, 24533.88it/s]
# Tokenizing:  47%|████▋     | 23659/50000 [00:01<00:01, 24364.59it/s]
# Tokenizing:  52%|█████▏    | 26096/50000 [00:01<00:00, 24106.42it/s]
# Tokenizing:  57%|█████▋    | 28741/50000 [00:01<00:00, 24785.12it/s]
# Tokenizing:  63%|██████▎   | 31517/50000 [00:01<00:00, 25601.17it/s]
# Tokenizing:  68%|██████▊   | 34083/50000 [00:01<00:00, 25587.54it/s]
# Tokenizing:  73%|███████▎  | 36644/50000 [00:01<00:00, 25537.80it/s]
# Tokenizing:  78%|███████▊  | 39199/50000 [00:01<00:00, 25096.10it/s]
# Tokenizing:  83%|████████▎ | 41711/50000 [00:01<00:00, 24948.60it/s]
# Tokenizing:  88%|████████▊ | 44208/50000 [00:01<00:00, 24681.69it/s]
# Tokenizing:  93%|█████████▎| 46678/50000 [00:01<00:00, 24112.24it/s]
# Tokenizing:  99%|█████████▊| 49298/50000 [00:02<00:00, 24669.56it/s]
# Tokenizing: 100%|██████████| 50000/50000 [00:02<00:00, 24227.44it/s]
# Loading tokenizer and model: Salesforce/codet5p-220m
# Model loaded.
# Embedding matrix shape: torch.Size([32100, 768])
#   Vocab size:     32100
#   Embedding dim:  768
# Loaded 1000 samples from val_code.txt
#
# Token length stats:
#   Mean: 83.8
#   Max:  512
#   Min:  10
#
# Saved to val_code.pt
# Tokenizing:   0%|          | 0/1000 [00:00<?, ?it/s]
# Tokenizing:  40%|███▉      | 395/1000 [00:00<00:00, 3928.16it/s]
# Tokenizing:  88%|████████▊ | 883/1000 [00:00<00:00, 4486.48it/s]
# Tokenizing: 100%|██████████| 1000/1000 [00:00<00:00, 4576.61it/s]
# Loading tokenizer and model: Salesforce/codet5p-220m
# Model loaded.
# Embedding matrix shape: torch.Size([32100, 768])
#   Vocab size:     32100
#   Embedding dim:  768
# Loaded 1000 samples from val_summary.txt
#
# Token length stats:
#   Mean: 13.4
#   Max:  61
#   Min:  5
#
# Saved to val_summary.pt
# Tokenizing:   0%|          | 0/1000 [00:00<?, ?it/s]
# Tokenizing: 100%|██████████| 1000/1000 [00:00<00:00, 19206.18it/s]

# %% [markdown]
# # Load Dataset into Notebook

# %%
#!pip install torch

# %%
import torch
import torch.nn as nn

data = torch.load("train_code.pt")

# plug directly into your LSTM
embedding_layer = nn.Embedding.from_pretrained(
data['embedding_matrix'], freeze=False)

# feed into the LSTM
token_ids = data['token_ids']

# Useful constants
pad_id = data['pad_token_id']
eos_id = data['eos_token_id']
vocab_size = data['vocab_size']
embedding_dim = data['embedding_dim']

# %% [markdown]
# # Configuration

# %%
BATCH_SIZE = 64
MAX_LEN = 120
HIDDEN_DIM = 512
NUM_EPOCHS = 100
EVAL_STEPS = 2000 # increased to shorten training time
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#DEVICE = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# # Dataset and DataLoader

# %%
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch

class SummaryDataset(Dataset):
    def __init__(self, code_ids, summary_ids):
        self.code_ids = code_ids
        self.summary_ids = summary_ids

    def __len__(self):
        return len(self.code_ids)

    def __getitem__(self, idx):
        return (torch.tensor(self.code_ids[idx], dtype=torch.long),
            torch.tensor(self.summary_ids[idx], dtype=torch.long))

def collate_fn(batch):
    src_batch, tgt_batch = zip(*batch)

    src_batch = pad_sequence(src_batch, batch_first=True, padding_value=pad_id)
    tgt_batch = pad_sequence(tgt_batch, batch_first=True, padding_value=pad_id)

    return src_batch, tgt_batch

# Load train data
train_code = torch.load("train_code.pt")['token_ids']
train_summary = torch.load("train_summary.pt")['token_ids']

train_dataset = SummaryDataset(train_code, train_summary)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_fn)

# Load validation data
val_code = torch.load("val_code.pt")['token_ids']
val_summary = torch.load("val_summary.pt")['token_ids']

# Create validation dataset
val_dataset = SummaryDataset(val_code, val_summary)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# # LSTM Model

# %%
class Model(nn.Module):
    def __init__(self, vocab_size, embedding_dim, pad_id, sos_id, eos_id, pretrained_embeddings):
        super().__init__()
        self.embed = nn.Embedding.from_pretrained(
        pretrained_embeddings, freeze=False, padding_idx=pad_id)
        self.projection = None

        self.dropout = nn.Dropout(0.2)
        self.encoder = nn.LSTM(HIDDEN_DIM, HIDDEN_DIM, 2, batch_first=True, dropout=0.2)
        self.decoder = nn.LSTM(HIDDEN_DIM, HIDDEN_DIM, 2, batch_first=True, dropout=0.2)
        self.out = nn.Linear(HIDDEN_DIM, vocab_size)
        self.projection = nn.Linear(embedding_dim, HIDDEN_DIM)

        self.sos_id = sos_id
        self.eos_id = eos_id

    def _embed(self, x):
        e = self.embed(x)
        e = self.projection(e)
        return self.dropout(e)

    def forward(self, src, tgt):
        _, hidden = self.encoder(self._embed(src))
        output, _ = self.decoder(self._embed(tgt), hidden)
        return self.out(output)

    def generate(self, src):
        _, hidden = self.encoder(self._embed(src))
        outputs = []

        input_tok = torch.tensor([[self.sos_id]]).to(src.device)

        for _ in range(MAX_LEN):
            out, hidden = self.decoder(self._embed(input_tok), hidden)
            pred = self.out(out).argmax(-1)

            if pred.item() == self.eos_id:
                break

            outputs.append(pred.item())
            input_tok = pred

        return outputs

# %% [markdown]
# # Evaluation

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (2.6.0)
# Requirement already satisfied: portalocker in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (2026.2.28)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (0.10.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sacrebleu) (6.0.2)
# Requirement already satisfied: pywin32>=226 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from portalocker->sacrebleu) (311)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sacrebleu.metrics import BLEU

def compute_bleu(model, val_loader, tokenizer, max_samples=500):
    model.eval()
    predictions = []
    references = []
    seen = 0

    with torch.no_grad():
        for src, tgt in val_loader:
            src, tgt = src.to(DEVICE), tgt.to(DEVICE)

            batch_preds = []
            for i in range(src.size(0)):
                pred_ids = model.generate(src[i:i+1])
                batch_preds.append(pred_ids)

            for i in range(src.size(0)):
                if seen >= max_samples:
                    break
                pred_text = tokenizer.decode(
                    batch_preds[i],
                    skip_special_tokens=True)
                gold_text = tokenizer.decode(
                    tgt[i].tolist(),
                    skip_special_tokens=True)
                predictions.append(pred_text)
                references.append(gold_text)
                seen += 1
            if seen >= max_samples:
                break
    bleu_metric = BLEU(max_ngram_order=1)
    bleu = bleu_metric.corpus_score(predictions, [references])            
    '''bleu = sacrebleu.corpus_bleu(
        predictions,
        [references], n_gram=1 # only want bleu1 for early stopping
    )'''

    return bleu.score

# %% [markdown]
# # Train Model

# %%
import os
import torch
import torch.nn as nn
from torch.nn.utils import clip_grad_norm_
from tqdm import tqdm
import sacrebleu
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Salesforce/codet5p-220m")


best_bleu = 0
patience = 0

sos_id = 0 if data['pad_token_id'] != 0 else 1

model = Model(
    vocab_size=data['vocab_size'],
    embedding_dim=data['embedding_dim'],
    pad_id=data['pad_token_id'],
    eos_id=data['eos_token_id'],
    sos_id=sos_id,
    pretrained_embeddings=data['embedding_matrix']
).to(DEVICE)

save_dir = "checkpoints"
os.makedirs(save_dir, exist_ok=True)
save_name = f"lstm_codet5_small"

criterion = nn.CrossEntropyLoss(ignore_index=pad_id)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4) # lower learning rate


steps_per_epoch = len(train_loader)
total_steps = NUM_EPOCHS * steps_per_epoch

step = 0
running_loss = 0
LOG_STEPS = 50

progress = tqdm(total=total_steps, desc="Training")

for epoch in range(NUM_EPOCHS):
    model.train()

    for src, tgt in train_loader:
        src, tgt = src.to(DEVICE), tgt.to(DEVICE)

        optimizer.zero_grad()

        tgt_input = tgt[:, :-1]
        tgt_output = tgt[:, 1:]

        logits = model(src, tgt_input)

        loss = criterion(
            logits.reshape(-1, vocab_size),
            tgt_output.reshape(-1)
        )

        loss.backward()
        clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        step += 1
        running_loss += loss.item()

        if step % LOG_STEPS == 0:
            avg_loss = running_loss / LOG_STEPS
            progress.set_postfix({"loss": f"{avg_loss:.3f}", "epoch": epoch + 1})
            running_loss = 0

        progress.update(1)

        if step % EVAL_STEPS == 0:
            bleu = compute_bleu(model, val_loader, tokenizer, max_samples=100)
            tqdm.write(f"Step {step}/{total_steps} | BLEU-1 = {bleu:.4f}")

            if bleu > best_bleu:
                best_bleu = bleu
                patience = 0
                torch.save(model.state_dict(), f"{save_dir}/{save_name}.pt")
                tqdm.write("Saved best model")
            else:
                patience += 1
                tqdm.write(f"No improvement | Patience {patience}/10")
                if patience >= 10:
                    tqdm.write(f"\nEarly stopping at step {step}! Best BLEU-1: {best_bleu:.4f}")
                    progress.close()
                    break

            model.train()
    else:
        continue
    break

progress.close()
print(f"\nBest BLEU-1: {best_bleu:.4f}")
# Out:
# Training:   0%|          | 44/78200 [00:05<2:52:15,  7.56it/s]
# Training:   3%|▎         | 2000/78200 [03:28<1:52:00, 11.34it/s, loss=4.309, epoch=3]
# Step 2000/78200 | BLEU-1 = 2.9899
# Training:   3%|▎         | 2001/78200 [03:29<7:17:52,  2.90it/s, loss=4.309, epoch=3]
# Saved best model
# Training:   5%|▌         | 4000/78200 [06:54<1:56:55, 10.58it/s, loss=3.695, epoch=6]
# Step 4000/78200 | BLEU-1 = 13.7932
# Training:   5%|▌         | 4002/78200 [06:55<6:50:05,  3.02it/s, loss=3.695, epoch=6]
# Saved best model
# Training:   8%|▊         | 6002/78200 [10:20<6:40:16,  3.01it/s, loss=3.394, epoch=8]
# Step 6000/78200 | BLEU-1 = 11.8774
# No improvement | Patience 1/10
# Training:  10%|█         | 8002/78200 [13:45<6:22:41,  3.06it/s, loss=2.992, epoch=11]
# Step 8000/78200 | BLEU-1 = 11.9628
# No improvement | Patience 2/10
# Training:  13%|█▎        | 10001/78200 [17:17<6:27:47,  2.93it/s, loss=2.825, epoch=13]
# Step 10000/78200 | BLEU-1 = 13.3527
# No improvement | Patience 3/10
# Training:  15%|█▌        | 12001/78200 [20:41<8:28:55,  2.17it/s, loss=2.570, epoch=16]
# Step 12000/78200 | BLEU-1 = 12.3508
# No improvement | Patience 4/10
# Training:  18%|█▊        | 14002/78200 [24:12<5:56:44,  3.00it/s, loss=2.451, epoch=18]
# Step 14000/78200 | BLEU-1 = 13.1257
# No improvement | Patience 5/10
# Training:  20%|██        | 16000/78200 [27:37<1:24:18, 12.30it/s, loss=2.219, epoch=21]
# Step 16000/78200 | BLEU-1 = 15.7313
# Training:  20%|██        | 16000/78200 [27:37<1:24:18, 12.30it/s, loss=2.219, epoch=21]
# Saved best model
# Training:  23%|██▎       | 18002/78200 [31:08<5:27:19,  3.07it/s, loss=2.062, epoch=24]
# Step 18000/78200 | BLEU-1 = 14.9741
# No improvement | Patience 1/10
# Training:  26%|██▌       | 20000/78200 [34:37<1:28:34, 10.95it/s, loss=1.919, epoch=26]
# Step 20000/78200 | BLEU-1 = 17.1785
# Training:  26%|██▌       | 20002/78200 [34:38<6:41:01,  2.42it/s, loss=1.919, epoch=26]
# Saved best model
# Training:  28%|██▊       | 22002/78200 [38:03<5:34:41,  2.80it/s, loss=1.744, epoch=29]
# Step 22000/78200 | BLEU-1 = 16.4342
# No improvement | Patience 1/10
# Training:  31%|███       | 24000/78200 [41:29<1:23:05, 10.87it/s, loss=1.691, epoch=31]
# Step 24000/78200 | BLEU-1 = 19.0004
# Training:  31%|███       | 24001/78200 [41:30<5:52:28,  2.56it/s, loss=1.691, epoch=31]
# Saved best model
# Training:  33%|███▎      | 26002/78200 [45:00<5:08:18,  2.82it/s, loss=1.495, epoch=34]
# Step 26000/78200 | BLEU-1 = 18.9941
# No improvement | Patience 1/10
# Training:  36%|███▌      | 28001/78200 [48:25<4:51:56,  2.87it/s, loss=1.528, epoch=36]
# Step 28000/78200 | BLEU-1 = 16.8039
# No improvement | Patience 2/10
# Training:  38%|███▊      | 30002/78200 [51:50<4:45:16,  2.82it/s, loss=1.394, epoch=39]
# Step 30000/78200 | BLEU-1 = 18.9124
# No improvement | Patience 3/10
# Training:  41%|████      | 32002/78200 [55:19<4:24:59,  2.91it/s, loss=1.397, epoch=41]
# Step 32000/78200 | BLEU-1 = 15.8073
# No improvement | Patience 4/10
# Training:  43%|████▎     | 34000/78200 [58:49<1:45:31,  6.98it/s, loss=1.252, epoch=44]
# Step 34000/78200 | BLEU-1 = 20.9352
# Training:  43%|████▎     | 34002/78200 [58:49<5:18:29,  2.31it/s, loss=1.252, epoch=44]
# Saved best model
# Training:  46%|████▌     | 36001/78200 [1:02:12<4:06:38,  2.85it/s, loss=1.184, epoch=47]
# Step 36000/78200 | BLEU-1 = 17.6696
# No improvement | Patience 1/10
# Training:  49%|████▊     | 38001/78200 [1:05:38<4:04:34,  2.74it/s, loss=1.137, epoch=49]
# Step 38000/78200 | BLEU-1 = 18.3778
# No improvement | Patience 2/10
# Training:  51%|█████     | 40002/78200 [1:09:06<3:44:39,  2.83it/s, loss=1.002, epoch=52]
# Step 40000/78200 | BLEU-1 = 19.0100
# No improvement | Patience 3/10
# Training:  54%|█████▎    | 42002/78200 [1:12:34<3:34:36,  2.81it/s, loss=1.067, epoch=54]
# Step 42000/78200 | BLEU-1 = 19.0917
# No improvement | Patience 4/10
# Training:  56%|█████▋    | 44002/78200 [1:16:02<3:22:25,  2.82it/s, loss=0.941, epoch=57]
# Step 44000/78200 | BLEU-1 = 19.6322
# No improvement | Patience 5/10
# Training:  59%|█████▉    | 46002/78200 [1:19:30<3:12:48,  2.78it/s, loss=0.938, epoch=59]
# Step 46000/78200 | BLEU-1 = 18.8193
# No improvement | Patience 6/10
# Training:  61%|██████▏   | 48002/78200 [1:22:58<3:01:02,  2.78it/s, loss=0.865, epoch=62]
# Step 48000/78200 | BLEU-1 = 19.4337
# No improvement | Patience 7/10
# Training:  64%|██████▍   | 50001/78200 [1:26:26<3:10:38,  2.47it/s, loss=0.865, epoch=64]
# Step 50000/78200 | BLEU-1 = 18.8189
# No improvement | Patience 8/10
# Training:  66%|██████▋   | 52000/78200 [1:29:46<38:29, 11.34it/s, loss=0.792, epoch=67]
# Step 52000/78200 | BLEU-1 = 19.3728
# No improvement | Patience 9/10
# Training:  69%|██████▉   | 54000/78200 [1:33:14<41:47,  9.65it/s, loss=0.742, epoch=70]
# Step 54000/78200 | BLEU-1 = 18.9506
# No improvement | Patience 10/10
#
# Early stopping at step 54000! Best BLEU-1: 20.9352
#
# Best BLEU-1: 20.9352

# %% [markdown]
# # BLEU 1,2,3,4

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.7 MB 10.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.7 MB 10.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.1 MB/s eta 0:00:00
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-3.0.1 tzdata-2025.3
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import torch
import sacrebleu
from tqdm import tqdm
from sacrebleu.metrics import BLEU

# load test file
df = pd.read_csv("test_dataset_tokenized.csv")

# Convert references to CodeT5 subword tokens
references_tokens = []
for ref in df["summary_tokens"]:
    ref_ids = tokenizer.encode(ref, add_special_tokens=False)
    ref_tokens = [tokenizer._convert_id_to_token(id) for id in ref_ids]
    references_tokens.append([" ".join(ref_tokens)])

# load best model
model = Model(
    vocab_size=data['vocab_size'],
    embedding_dim=data['embedding_dim'],
    pad_id=data['pad_token_id'],
    eos_id=data['eos_token_id'],
    sos_id=sos_id,
    pretrained_embeddings=data['embedding_matrix']
).to(DEVICE)

model.load_state_dict(torch.load("checkpoints/lstm_codet5_small.pt", map_location=DEVICE))
model.eval()

predictions = []

predictions_tokens = []
for ids in tqdm(df["code_ids"]):
    src = torch.tensor(eval(ids)).unsqueeze(0).to(DEVICE)
    pred_ids = model.generate(src)

    # convert predicted ids to subword tokens
    pred_tokens = [tokenizer._convert_id_to_token(i) for i in pred_ids]
    predictions_tokens.append(" ".join(pred_tokens))

# Convert references to subword tokens (same as predictions)
references_tokens = []
for ref in df["summary_tokens"]:
    ref_ids = tokenizer.encode(ref, add_special_tokens=False)
    ref_tokens = [tokenizer._convert_id_to_token(i) for i in ref_ids]
    references_tokens.append([" ".join(ref_tokens)])  # sacrebleu expects list of lists

# Compute BLEU
bleu1 = BLEU(max_ngram_order=1).corpus_score(predictions_tokens, references_tokens)
bleu2 = BLEU(max_ngram_order=2).corpus_score(predictions_tokens, references_tokens)
bleu3 = BLEU(max_ngram_order=3).corpus_score(predictions_tokens, references_tokens)
bleu4 = BLEU(max_ngram_order=4).corpus_score(predictions_tokens, references_tokens)

print("BLEU-1:", bleu1.score)
print("BLEU-2:", bleu2.score)
print("BLEU-3:", bleu3.score)
print("BLEU-4:", bleu4.score)
# Out:
# 100%|██████████| 99/99 [00:01<00:00, 93.62it/s]
# BLEU-1: 6.112226356887866
# BLEU-2: 3.1809034470435544
# BLEU-3: 2.0905169555026206
# BLEU-4: 1.4594726822668644

# %% [markdown]
# # METEOR

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.5 MB/s eta 0:00:00
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: click, nltk
# Successfully installed click-8.3.1 nltk-3.9.3
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from nltk.translate.meteor_score import single_meteor_score
import torch
from transformers import AutoTokenizer

df = pd.read_csv("test_dataset_tokenized.csv")

model = Model(
    vocab_size=data['vocab_size'],
    embedding_dim=data['embedding_dim'],
    pad_id=data['pad_token_id'],
    eos_id=data['eos_token_id'],
    sos_id=sos_id,
    pretrained_embeddings=data['embedding_matrix']
).to(DEVICE)
model.eval()

tokenizer = AutoTokenizer.from_pretrained("Salesforce/codet5p-220m", add_prefix_space=True)

token_ids = data["token_ids"] 


def decode_with_codet5(lstm_ids):
    words = []
    for i in lstm_ids:
        if i in [data['pad_token_id'], data['eos_token_id']]:
            continue
        if i < len(token_ids):
            words.append(str(token_ids[i]))

    if not words:
        return ""
    
    encoded = tokenizer(words, is_split_into_words=True, add_special_tokens=False)
    code_t5_ids = encoded["input_ids"]

    return tokenizer.decode(code_t5_ids, skip_special_tokens=True)

predictions = []

MAX_LEN = 512

src = torch.tensor(eval(ids)[:MAX_LEN]).unsqueeze(0).to(DEVICE) 

with torch.no_grad():
    for ids in df["code_ids"]:
        src = torch.tensor(eval(ids)).unsqueeze(0).to(DEVICE)

        pred_ids = model.generate(src)

        pred_text = decode_with_codet5(pred_ids)

        if not pred_text.strip():
            pred_text = "<empty>"

        predictions.append(pred_text)

MAX_LEN = 512
meteor_scores = []

with torch.no_grad():
    for ids, ref in zip(df["code_ids"], df["summary"]):
        # Truncate the input to MAX_LEN tokens
        token_list = eval(ids)[:MAX_LEN]
        src = torch.tensor(token_list).unsqueeze(0).to(DEVICE)
        pred_ids = model.generate(src)

        # Decode to text
        pred_text = decode_with_codet5(pred_ids).strip()
        if not pred_text:
            pred_text = "<empty>"

        # Tokenize
        ref_tokens = ref.split()
        pred_tokens = pred_text.split()

        # Compute METEOR
        if pred_tokens == ["<empty>"]:
            meteor_scores.append(0.0)
        else:
            meteor_scores.append(single_meteor_score(ref_tokens, pred_tokens))

# Average METEOR
avg_meteor = sum(meteor_scores) / len(meteor_scores)
print("Average METEOR:", avg_meteor)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (193832 > 512). Running this sequence through the model will result in indexing errors
# Average METEOR: 0.0

# %% [markdown]
# # BERTScore

# %%
# !pip install bert-score
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (2.6.0.dev20241112+cu121)
# Requirement already satisfied: pandas>=1.0.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (3.0.1)
# Requirement already satisfied: transformers>=3.0.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (4.46.0)
# Requirement already satisfied: numpy in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (1.26.4)
# Requirement already satisfied: requests in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (2.32.5)
# Requirement already satisfied: tqdm>=4.31.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (4.67.3)
# Collecting matplotlib (from bert-score)
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from bert-score) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from pandas>=1.0.1->bert-score) (2025.3)
# Requirement already satisfied: filelock in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: networkx in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (2026.2.0)
# Requirement already satisfied: setuptools in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from tqdm>=4.31.1->bert-score) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers>=3.0.0->bert-score) (0.36.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers>=3.0.0->bert-score) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers>=3.0.0->bert-score) (0.7.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Collecting contourpy>=1.0.1 (from matplotlib->bert-score)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->bert-score)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->bert-score)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->bert-score)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=8 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from matplotlib->bert-score) (12.1.0)
# Collecting pyparsing>=3 (from matplotlib->bert-score)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->bert-score) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->bert-score) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->bert-score) (2026.2.25)
# Requirement already satisfied: six>=1.5 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------------------------- ------------ 5.5/8.1 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 28.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 26.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, bert-score
# Successfully installed bert-score-0.3.13 contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.2
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from bert_score import score

# Load test dataset
df = pd.read_csv("test_dataset_tokenized.csv")

# load best model
model = Model(
    vocab_size=data['vocab_size'],
    embedding_dim=data['embedding_dim'],
    pad_id=data['pad_token_id'],
    eos_id=data['eos_token_id'],
    sos_id=sos_id,
    pretrained_embeddings=data['embedding_matrix']
).to(DEVICE)

tokenizer = AutoTokenizer.from_pretrained("Salesforce/codet5p-220m")
model.eval()

predictions = []
references = []

# Generate predictions from your LSTM
for ids, ref_text in tqdm(zip(df["code_ids"], df["summary"]), total=len(df)):
    src = torch.tensor(eval(ids)).unsqueeze(0).to(DEVICE)

    pred_ids = model.generate(src)
    pred_text = tokenizer.decode(pred_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True)
    
    predictions.append(pred_text)
    references.append(ref_text)


# compute BERTScore
P, R, F1 = score(predictions, references, lang="en", rescale_with_baseline=True)

# Print average
print(f"BERTScore Precision: {P.mean().item():.4f}")
print(f"BERTScore Recall:    {R.mean().item():.4f}")
print(f"BERTScore F1:        {F1.mean().item():.4f}")
# Out:
# 100%|██████████| 99/99 [00:06<00:00, 15.09it/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore Precision: -1.0853
# BERTScore Recall:    -0.1549
# BERTScore F1:        -0.6684

# %% [markdown]
# # SIDE

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (4.46.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (2.6.0.dev20241112+cu121)
# Requirement already satisfied: numpy in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (1.26.4)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: filelock in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: networkx in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Collecting joblib>=1.3.0 (from scikit-learn->sentence-transformers)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron\downloads\abby_project\abby_venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2026.2.25)
# Downloading sentence_transformers-5.2.3-py3-none-any.whl (494 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.0 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.0 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 17.8 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ------ --------------------------------- 5.8/36.5 MB 27.1 MB/s eta 0:00:02
#    ------------ --------------------------- 11.8/36.5 MB 28.4 MB/s eta 0:00:01
#    ------------------- -------------------- 17.6/36.5 MB 27.7 MB/s eta 0:00:01
#    ------------------------- -------------- 23.3/36.5 MB 28.4 MB/s eta 0:00:01
#    -------------------------------- ------- 29.6/36.5 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.5 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 27.3 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sentence-transformers
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 sentence-transformers-5.2.3 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import util
from transformers import AutoTokenizer, AutoModel, T5EncoderModel
import torch
import torch.nn.functional as F

# Mean Pooling - Take attention mask into account
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# Use encoder-only T5 model
checkPointFolder = "Salesforce/codet5p-220m"
tokenizer = AutoTokenizer.from_pretrained(checkPointFolder)
model = T5EncoderModel.from_pretrained(checkPointFolder).to(DEVICE)
model.eval()

# Example code snippet and summary
method = """
  public Object pop() throws EmptyStackException {
        try {
            Object aObject = this.stackElements.get(stackElements.size() - 1);
            stackElements.remove(stackElements.size() - 1);
            return aObject;
        } catch (Exception e) {
            throw new EmptyStackException(e);
        }
    }
"""
codeSummary = "pop the top of the stack"

pair = [method, codeSummary]

# Tokenize
encoded_input = tokenizer(pair, padding=True, truncation=True, return_tensors='pt').to(DEVICE)

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Mean pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

sim = util.pytorch_cos_sim(sentence_embeddings[0], sentence_embeddings[1]).item()

print(sim)
# Out:
# 0.414553165435791
